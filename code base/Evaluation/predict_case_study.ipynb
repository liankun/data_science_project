# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
predict1_df = pd.read_csv("fstAggPrediction (1).csv")

# %%
predict1_df.head()
# Out:
#    Unnamed: 0  zip  college_cnt_fst_agg  walmart_cnt_fst_agg  \
# 0           0  602             0.002777             0.000973
# 1           1  610             0.000000             0.000000
# 2           2  616             0.000000             0.000000
# 3           3  623             0.000000             0.002627
# 4           4  624             0.000000             0.000000
#
#    Num_Mcdonalds_fst_agg  Num_Starbucks_fst_agg  Num_Teavana_fst_agg  \
# 0               0.000000                    0.0                  0.0
# 1               0.000530                    0.0                  0.0
# 2               0.000641                    0.0                  0.0
# 3               0.001217                    0.0                  0.0
# 4               0.000000                    0.0                  0.0
#
#    population_total_fst_agg  pop_under19_fst_agg  pop_19To34_fst_agg  ...  \
# 0                  0.005878             0.005337            0.005694  ...
# ...

# %%
predict2_df = pd.read_csv("sndAggPrediction (1).csv")

# %%
predict2_df.head()
# Out:
#    Unnamed: 0  zip  college_cnt_snd_agg  walmart_cnt_snd_agg  \
# 0           0  623             0.000000             0.004203
# 1           1  636             0.001790             0.000331
# 2           2  641             0.000000             0.000000
# 3           3  656             0.001598             0.000000
# 4           4  660             0.000093             0.000000
#
#    Num_Mcdonalds_snd_agg  Num_Starbucks_snd_agg  Num_Teavana_snd_agg  \
# 0               0.001947               0.000000                  0.0
# 1               0.000153               0.000119                  0.0
# 2               0.000000               0.000000                  0.0
# 3               0.003102               0.001540                  0.0
# 4               0.000335               0.000000                  0.0
#
#    population_total_snd_agg  pop_under19_snd_agg  pop_19To34_snd_agg  ...  \
# 0                  0.008281             0.008169            0.008293  ...
# ...

# %%
predict1_df.
# Out:
# Unnamed: 0                                 int64
# zip                                        int64
# college_cnt_fst_agg                      float64
# walmart_cnt_fst_agg                      float64
# Num_Mcdonalds_fst_agg                    float64
# Num_Starbucks_fst_agg                    float64
# Num_Teavana_fst_agg                      float64
# population_total_fst_agg                 float64
# pop_under19_fst_agg                      float64
# pop_19To34_fst_agg                       float64
# pop_35To54_fst_agg                       float64
# pop_55AndOver_fst_agg                    float64
# pop_male_fst_agg                         float64
# pop_female_fst_agg                       float64
# pop_white_fst_agg                        float64
# pop_black_fst_agg                        float64
# pop_asian_fst_agg                        float64
# pop_latino_fst_agg                       float64
# pop_inMarriedCoupleFamily_fst_agg        float64
# ...

# %%
predict1_df.shape
# Out:
# (8975, 35)

# %%
predict1_df.sort_values(by=['LABEL_bubbleStore_cnt_fst_agg'],ascending=True)['zip'][8975//2]
# Out:
# 49460

# %%
predict1_df.describe()
# Out:
#         Unnamed: 0           zip  college_cnt_fst_agg  walmart_cnt_fst_agg  \
# count  8975.000000   8975.000000          8975.000000          8975.000000
# mean   4487.000000  48605.724903             0.000716             0.001005
# std    2591.003667  27723.715619             0.001891             0.002352
# min       0.000000    602.000000             0.000000             0.000000
# 25%    2243.500000  24484.000000             0.000000             0.000000
# 50%    4487.000000  49460.000000             0.000000             0.000000
# 75%    6730.500000  71436.500000             0.000826             0.001252
# max    8974.000000  99927.000000             0.038522             0.026266
#
#        Num_Mcdonalds_fst_agg  Num_Starbucks_fst_agg  Num_Teavana_fst_agg  \
# count            8975.000000            8975.000000          8975.000000
# mean                0.001322               0.000526             0.000065
# ...

# %%
predict1_df['college_cnt_fst_agg'].std()
# Out:
# 0.0018910789779465157

# %%
cand_zipcode = 38017
labels=[]
deviation=[]
for col in predict1_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_fst_agg":
        continue
    labels.append(col)
    val = predict1_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict1_df[col].mean()
    d = predict1_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# <BarContainer object of 32 artists>

# %%
cand_zipcode = 80510
labels=[]
deviation=[]
for col in predict1_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_fst_agg":
        continue
    labels.append(col)
    val = predict1_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict1_df[col].mean()
    d = predict1_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# <BarContainer object of 32 artists>

# %%
predict1_df['LABEL_bubbleStore_cnt_fst_agg'].sor
# Out:
# 9.81639e-05

# %%
cand_zipcode =  49460
labels=[]
deviation=[]
for col in predict1_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_fst_agg":
        continue
    labels.append(col)
    val = predict1_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict1_df[col].mean()
    d = predict1_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# <BarContainer object of 32 artists>

# %%
predict2_df.shape
# Out:
# (5417, 35)

# %%
#second dataset
predict2_df.sort_values(by=['LABEL_bubbleStore_cnt_snd_agg'],ascending=True)['zip'][5417//2]
# Out:
# 49279

# %%
cand_zipcode = 38017
labels=[]
deviation=[]
for col in predict2_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_snd_agg":
        continue
    labels.append(col)
    val = predict2_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict2_df[col].mean()
    d = predict2_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# F:\Users\zzguk\Anaconda3\envs\NTUHW\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# <BarContainer object of 32 artists>

# %%
#star buck
cand_zipcode = 33744
labels=[]
deviation=[]
for col in predict2_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_snd_agg":
        continue
    labels.append(col)
    val = predict2_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict2_df[col].mean()
    d = predict2_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# F:\Users\zzguk\Anaconda3\envs\NTUHW\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# <BarContainer object of 32 artists>

# %%
#star buck
cand_zipcode = 49279
labels=[]
deviation=[]
for col in predict2_df.columns:
    if col == 'Unnamed: 0' or col == 'zip' or col == "LABEL_bubbleStore_cnt_snd_agg":
        continue
    labels.append(col)
    val = predict2_df[predict1_df['zip']==cand_zipcode][col].values[0]
    m = predict2_df[col].mean()
    d = predict2_df[col].std()
    if d!=0:
        deviation.append((val-m)/d)
    else:
        deviation.append(0)
    #print(col)
    #print(val)
plt.figure(figsize=(10,10))
plt.barh(labels,deviation)
# Out:
# F:\Users\zzguk\Anaconda3\envs\NTUHW\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# <BarContainer object of 32 artists>
